# %%
from config import STOCKNET_CONFIG
from parsers import StocknetParser, SP500Parser
import numpy as np

# %%
parser = SP500Parser('SP500/SP500_all.csv', min_trading_days=1259)

# %%
data = parser.get_scenario("../data/SP_new.npy")

# %%
np.save("../data/SP500_new.np", data.T)
data.shape
# Out:
# (491, 4278)

# %%
# Out:
# (470, 1258)

# %%
parser = StocknetParser(STOCKNET_CONFIG["DATA_PATH"], excluded_stocks=STOCKNET_CONFIG["EXCLUDED_STOCKS"])

# %%
data = parser.get_scenario("../data/stocknet_80.npy")

# %%
np.save("../data/stocknet_80.npy", data.T)
