# %%
from scipy.stats import ks_2samp, gaussian_kde, wasserstein_distance
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm
from factor_model import load_model
from metrics.statistic import compute_corr
from scenario_generator import *
import yaml

_exp = "temporal_cond"

# %%
PREFIX = f"model/{_exp}"
with open(f"{PREFIX}/cfg.yaml") as f:
    _cfg = yaml.safe_load(f)

FACTOR_NAMES = _cfg["factors"]
NUM_GENERATE = _cfg["num_generate"]
CKPT_PATH = f"{PREFIX}/checkpoints/{_cfg['ckpt_name']}.pt"
seq_len = _cfg['seq_len']
model = load_model(PREFIX)
test_model = load_model(f"{PREFIX}/test")
print(PREFIX, NUM_GENERATE)
# Out:
# model/temporal_cond 500

# %%
_cfg
# Out:
# {'characteristics': ['growth',
#   'momentum',
#   'quality',
#   'size',
#   'value',
#   'volatility'],
#  'factors': ['market',
#   'growth',
#   'momentum',
#   'quality',
#   'size',
#   'value',
#   'volatility'],
#  'train_path': 'data/train24y.parquet',
#  'test_path': 'data/test1y.parquet',
#  'data_file': 'factors.csv',
#  'vix_file': 'data/VIXCLS.csv',
#  'epochs': 200,
#  'batch_size': 64,
#  'lr': 0.0001,
#  'num_timesteps': 100,
#  'levy_alpha': 2.0,
#  'ckpt_name': 'cond_another',
#  'num_generate': 500,
#  'seq_len': 22,
#  'cond_drop_prob': 0.1,
#  'cond_drop_prob_vix': 0.15,
#  'ema_decay': 0.999}

# %% [markdown]
# ## Marginal Statistics
#
# trajactory aggregated as 1 value

# %%
def _aggregate(fs, op = 1):
    if op == 1:
        return np.log1p(fs).sum(axis=-1)
    else:
        nums, factors, timestamps = fs.shape
        return fs.transpose(0, 2, 1).reshape(nums * timestamps, factors)

# %%
import os

diffusionScenario = ScenarioGenerator(model, DiffusionSampler(CKPT_PATH))
scaler = diffusionScenario.sampler.scaler

path_cache = f"{PREFIX}/samples/path_{NUM_GENERATE}x{seq_len}.npy"
if os.path.exists(path_cache):
    diffusion_temporal = np.load(path_cache)
else:
    diffusion_temporal = diffusionScenario.sampler.sample_temporal(NUM_GENERATE, seq_len)
    os.makedirs(f"{PREFIX}/samples", exist_ok=True)
    np.save(path_cache, diffusion_temporal)
diffusion_temporal.shape
sampled = _aggregate(diffusion_temporal)

# %%
# training ds
train = model.F

# get the resampled baseline
gaussionSampler = GaussianSampler(train, scaler)
gaussian_temporal = gaussionSampler.sample_temporal(NUM_GENERATE,  seq_len)
sampled_gaussian = _aggregate(gaussian_temporal)

# %%
OOS = test_model.F.drop(columns=['alpha']).values
resampleSampler = ResampleSampler(train, scaler)
resample_temporal = resampleSampler.sample_temporal(NUM_GENERATE , seq_len)
resample = _aggregate(resample_temporal)

windows = np.lib.stride_tricks.sliding_window_view(OOS, seq_len, axis=0)
OOS_temporal = np.ascontiguousarray(windows)
OOS = _aggregate(OOS_temporal)

baselines = [("Resample", resample, '#17becf'), ("Gaussion", sampled_gaussian, '#ff7f0e')]
resample.shape, OOS.shape, sampled_gaussian.shape, sampled.shape
# Out:
# ((500, 7), (239, 7), (500, 7), (500, 7))

# %%
# 2.1 Moment Comparison
def compute_moments(data):
    return [np.mean(data, axis=0), np.std(data, axis=0),
            stats.skew(data, axis=0), stats.kurtosis(data, axis=0)]


moment_names = ['Mean', 'Std', 'Skewness', 'Kurtosis']
m_OOS    = compute_moments(OOS)
m_gen    = compute_moments(sampled)
m_bases  = [(name, compute_moments(data), c) for name, data, c in baselines]

ANNOT_FS = 4
LEGEND_FS = 6
PT_SIZE   = 40

fig, axes = plt.subplots(2, 2, figsize=(10, 9))
for idx, (ax, mname) in enumerate(zip(axes.flatten(), moment_names)):
    OOS_m = m_OOS[idx]
    gen_m = m_gen[idx]
    all_y = [gen_m] + [bm[idx] for _, bm, _ in m_bases]

    lim = [min(OOS_m.min(), min(y.min() for y in all_y)),
           max(OOS_m.max(), max(y.max() for y in all_y))]
    pad = (lim[1] - lim[0]) * 0.15 or 0.01
    lim = [lim[0] - pad, lim[1] + pad]

    ax.plot(lim, lim, 'k--', lw=1, alpha=0.5)
    ax.scatter(OOS_m, gen_m, color='#2ca02c', s=PT_SIZE, marker='o', zorder=4,
               label='Generated', alpha=0.9)
    for i, fn in enumerate(FACTOR_NAMES):
        ax.annotate(fn, (OOS_m[i], gen_m[i]), fontsize=ANNOT_FS,
                    xytext=(3, 2), textcoords='offset points', color='#2ca02c')
    for (bname, bm, bc) in m_bases:
        ax.scatter(OOS_m, bm[idx], color=bc, s=PT_SIZE, marker='s', zorder=3,
                   label=bname, alpha=0.8)
        for i, fn in enumerate(FACTOR_NAMES):
            ax.annotate(fn, (OOS_m[i], bm[idx][i]), fontsize=ANNOT_FS,
                        xytext=(3, 2), textcoords='offset points', color=bc)

    ax.set_xlim(lim); ax.set_ylim(lim)
    ax.set_xlabel('OOS')
    ax.set_title(mname, fontweight='bold')
    ax.grid(True, alpha=0.3)
    ax.legend(fontsize=LEGEND_FS, markerscale=0.9, handlelength=1.2)

fig.suptitle('2.1 Moment Comparison', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
def fmt_mae(errs):
    return f"{np.mean(errs):.4f} ({np.std(errs):.4f})"

col_w = 22
header = f"{'Moment':<12}" + f"{'Generated':<{col_w}}" + \
         "".join(f"{bname:<{col_w}}" for bname, _, _ in m_bases)
print("MAE across factors — mean (std):")
print(header)
print("-" * len(header))
for idx, mname in enumerate(moment_names):
    row = f"{mname:<12}{fmt_mae(np.abs(m_gen[idx] - m_OOS[idx])):<{col_w}}"
    for _, bm, _ in m_bases:
        row += f"{fmt_mae(np.abs(bm[idx] - m_OOS[idx])):<{col_w}}"
    print(row)
# Out:
# MAE across factors — mean (std):
# Moment      Generated             Resample              Gaussion
# ------------------------------------------------------------------------------
# Mean        0.0030 (0.0031)       0.0028 (0.0023)       0.0032 (0.0026)
# Std         0.0022 (0.0011)       0.0035 (0.0044)       0.0030 (0.0028)
# Skewness    0.2964 (0.1799)       0.5345 (0.2412)       0.2841 (0.1939)
# Kurtosis    0.5920 (0.4037)       2.3316 (0.7579)       0.7275 (0.5521)

# %%
#Distribution Comparison (KDE)
n_factors = len(FACTOR_NAMES)
fig, axes = plt.subplots(2, 4, figsize=(16, 7))

for ax, name, i in zip(axes.flatten(), FACTOR_NAMES, range(n_factors)):
    OOS_vals    = OOS[:, i]
    gen_vals    = sampled[:, i]

    all_vals = np.concatenate([OOS_vals, gen_vals] +
                              [bdata[:, i] for _, bdata, _ in baselines])
    x_min, x_max = all_vals.min(), all_vals.max()
    pad = (x_max - x_min) * 0.05
    x = np.linspace(x_min - pad, x_max + pad, 300)

    for vals, label, color, ls, lw in [
        (OOS_vals,   'OOS',       'steelblue', '-', 1.8),
        (gen_vals,   'Generated', '#2ca02c',     '-', 1.8),
    ]:
        ax.plot(x, gaussian_kde(vals)(x), label=label, color=color, lw=lw, ls=ls)

    for (bname, bdata, bc) in baselines:
        ax.plot(x, gaussian_kde(bdata[:, i])(x),
                label=bname, color=bc, lw=1.4, ls='--')

    ax.set_title(name, fontweight='bold')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

for ax in axes.flatten()[n_factors:]:
    ax.set_visible(False)

fig.suptitle('Distribution Comparison (KDE)', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
col_w = 14
method_names = ['Generated'] + [bname for bname, _, _ in baselines]
header = f"{'Factor':<14}" + "".join(f"{m:<{col_w}}" for m in method_names)
print("Wasserstein-1 Distance")
print(header)
print("-" * len(header))
for i, name in enumerate(FACTOR_NAMES):
    vals = [wasserstein_distance(OOS[:, i], sampled[:, i])] + \
           [wasserstein_distance(OOS[:, i], bdata[:, i]) for _, bdata, _ in baselines]
    win = int(np.argmin(vals))
    row = f"{name:<14}"
    for j, v in enumerate(vals):
        cell = f"{v:.4f}" + (" *" if j == win else "")
        row += f"{cell:<{col_w}}"
    print(row)
avg_gen = np.mean([wasserstein_distance(OOS[:, i], sampled[:, i]) for i in range(n_factors)])
avgs_b  = [np.mean([wasserstein_distance(OOS[:, i], bdata[:, i]) for i in range(n_factors)])
           for _, bdata, _ in baselines]
# Out:
# Wasserstein-1 Distance
# Factor        Generated     Resample      Gaussion
# --------------------------------------------------------
# market        0.0070 *      0.0109        0.0104
# growth        0.0017 *      0.0022        0.0018
# momentum      0.0039 *      0.0045        0.0051
# quality       0.0016 *      0.0024        0.0022
# size          0.0015 *      0.0015        0.0028
# value         0.0074        0.0068 *      0.0073
# volatility    0.0084        0.0066 *      0.0069

# %%
# Quantile-Quantile (Q-Q) Plots
n_quantiles = 200
probs = np.linspace(0.01, 0.99, n_quantiles)
n_factors = len(FACTOR_NAMES)

fig, axes = plt.subplots(2, 4, figsize=(16, 7))

for ax, name, i in zip(axes.flatten(), FACTOR_NAMES, range(n_factors)):
    q_OOS  = np.quantile(OOS[:, i],      probs)
    q_gen  = np.quantile(sampled[:, i],  probs)

    all_q = [q_OOS, q_gen] + [np.quantile(bdata[:, i], probs) for _, bdata, _ in baselines]
    lim = [min(q.min() for q in all_q), max(q.max() for q in all_q)]

    for (bname, bdata, bc) in baselines:
        q_base = np.quantile(bdata[:, i], probs)
        ax.scatter(q_OOS, q_base, s=8, color=bc, zorder=3,
                   label=bname, alpha=0.7, marker='s')

    ax.scatter(q_OOS, q_gen, s=8, color='#2ca02c', zorder=4, label='Generated', alpha=0.9)

    ax.plot(lim, lim, 'k--', lw=1, alpha=0.6)
    ax.set_xlim(lim); ax.set_ylim(lim)
    ax.set_title(name, fontweight='bold')
    ax.set_xlabel('OOS Quantiles')
    ax.set_ylabel('Generated / Baseline Quantiles')
    ax.legend(fontsize=7)
    ax.grid(True, alpha=0.3)

# hide unused subplots
for ax in axes.flatten()[n_factors:]:
    ax.set_visible(False)

fig.suptitle('2.3 Q-Q Plots: Generated vs OOS', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# KS Test
ks_gen   = [ks_2samp(OOS[:, i], sampled[:, i]).pvalue for i in range(len(FACTOR_NAMES))]
ks_bases = [(bname, [ks_2samp(OOS[:, i], bdata[:, i]).pvalue
                     for i in range(len(FACTOR_NAMES))])
            for bname, bdata, _ in baselines]

col_w = 16
method_names = ['Generated'] + [bname for bname, _ in ks_bases]
header = f"{'Factor':<18} " + "".join(f"{m:<{col_w}}" for m in method_names)
print("KS p-value   (* = highest p-value = closest to OOS in that row)")
print(header)
print("-" * len(header))
for j, name in enumerate(FACTOR_NAMES):
    vals = [ks_gen[j]] + [bks[j] for _, bks in ks_bases]
    win  = int(np.argmax(vals))
    row  = f"{name:<18} "
    for k, v in enumerate(vals):
        cell = f"{v:.4f}" + (" *" if k == win else "")
        row += f"{cell:<{col_w}}"
    print(row)
# Out:
# KS p-value   (* = highest p-value = closest to OOS in that row)
# Factor             Generated       Resample        Gaussion
# -------------------------------------------------------------------
# market             0.0071 *        0.0009          0.0029
# growth             0.0000 *        0.0000          0.0000
# momentum           0.0000 *        0.0000          0.0000
# quality            0.0016 *        0.0000          0.0000
# size               0.3059 *        0.2478          0.0051
# value              0.0000          0.0000 *        0.0000
# volatility         0.0000          0.0000          0.0000 *

# %%
def corr_mat(data):
    return np.corrcoef(data, rowvar=False)

corr_train  = corr_mat(train.drop(columns=['alpha']).values)
corr_OOS  = corr_mat(OOS)
corr_gen  = corr_mat(sampled)
corr_base = [(bname, corr_mat(bdata), bc) for bname, bdata, bc in baselines]

all_corrs = [('OOS', corr_OOS, 'steelblue'),('train', corr_train, 'red'),
             ('Generated', corr_gen, '#2ca02c')] + corr_base

n = len(all_corrs)
fig, axes = plt.subplots(1, n, figsize=(4 * n, 4.2))
norm = TwoSlopeNorm(vmin=-1, vcenter=0, vmax=1)

for ax, (name, corr, _) in zip(axes, all_corrs):
    im = ax.imshow(corr, cmap='RdBu_r', norm=norm)
    ax.set_xticks(range(len(FACTOR_NAMES)))
    ax.set_yticks(range(len(FACTOR_NAMES)))
    ax.set_xticklabels(FACTOR_NAMES, rotation=45, ha='right', fontsize=8)
    ax.set_yticklabels(FACTOR_NAMES, fontsize=8)
    ax.set_title(name, fontweight='bold')
    for ii in range(len(FACTOR_NAMES)):
        for jj in range(len(FACTOR_NAMES)):
            ax.text(jj, ii, f'{corr[ii, jj]:.2f}', ha='center', va='center',
                    fontsize=6, color='white' if abs(corr[ii, jj]) > 0.5 else 'black')

fig.colorbar(im, ax=axes[-1], fraction=0.046, pad=0.04)
fig.suptitle('Correlation Matrix Heatmaps', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
print("Relative MAE Distance of Covariance Matrix")
print(f"  {'Generated':<16} {compute_corr(sampled, OOS):.4f}")
for bname, bdata, _ in baselines:
    print(f"  {bname:<16} {compute_corr(bdata, OOS):.4f}")

tmp = train.drop(columns=['alpha']).values
print(f"  {'train':<16} {compute_corr(tmp, OOS):.4f}")
# Out:
# Relative MAE Distance of Covariance Matrix
#   Generated        0.2042
#   Resample         0.2118
#   Gaussion         0.1857
#   train            0.1962

# %%
#Correlation Scatter Plot: Generated vs OOS
# Extract upper-triangular (off-diagonal) entries of each correlation matrix
import itertools

n_f = len(FACTOR_NAMES)
pair_labels = [f"{FACTOR_NAMES[i][:3]}-{FACTOR_NAMES[j][:3]}"
               for i, j in itertools.combinations(range(n_f), 2)]
idx_i, idx_j = zip(*itertools.combinations(range(n_f), 2))

def upper_tri(corr):
    return np.array([corr[i, j] for i, j in zip(idx_i, idx_j)])

corr_OOS_vec = upper_tri(corr_OOS)
corr_gen_vec = upper_tri(corr_gen)
corr_base_vecs = [(bname, upper_tri(bc_corr), bc)
                  for bname, bc_corr, bc in corr_base]

ANNOT_FS = 5
LEGEND_FS = 7
PT_SIZE   = 50

all_y_vecs = [corr_gen_vec] + [v for _, v, _ in corr_base_vecs]
lim = [min(corr_OOS_vec.min(), min(v.min() for v in all_y_vecs)),
       max(corr_OOS_vec.max(), max(v.max() for v in all_y_vecs))]
pad = (lim[1] - lim[0]) * 0.12 or 0.05
lim = [lim[0] - pad, lim[1] + pad]

fig, ax = plt.subplots(figsize=(7, 6))
ax.plot(lim, lim, 'k--', lw=1, alpha=0.5)

# Generated
ax.scatter(corr_OOS_vec, corr_gen_vec, color='#2ca02c', s=PT_SIZE,
           marker='o', zorder=4, label='Generated', alpha=0.9)
for k, lbl in enumerate(pair_labels):
    ax.annotate(lbl, (corr_OOS_vec[k], corr_gen_vec[k]),
                fontsize=ANNOT_FS, xytext=(3, 2),
                textcoords='offset points', color='#2ca02c')

# Baselines
for bname, bvec, bc in corr_base_vecs:
    ax.scatter(corr_OOS_vec, bvec, color=bc, s=PT_SIZE,
               marker='s', zorder=3, label=bname, alpha=0.8)
    for k, lbl in enumerate(pair_labels):
        ax.annotate(lbl, (corr_OOS_vec[k], bvec[k]),
                    fontsize=ANNOT_FS, xytext=(3, 2),
                    textcoords='offset points', color=bc)

ax.set_xlim(lim); ax.set_ylim(lim)
ax.set_xlabel('OOS Pairwise Correlation', fontsize=10)
ax.set_ylabel('Generated / Baseline Pairwise Correlation', fontsize=10)
ax.set_title('Correlation Scatter Plot: Generated vs OOS', fontweight='bold')
ax.legend(fontsize=LEGEND_FS, markerscale=0.9, handlelength=1.2)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Temporal result

# %% [markdown]
# ### 3 Temporal evaluation (true trajectory)

# %%
print(OOS_temporal.shape, resample_temporal.shape, gaussian_temporal.shape, diffusion_temporal.shape)
# Out:
# (239, 7, 22) (500, 7, 22) (500, 7, 22) (500, 7, 22)

# %%
tempo_sets = [
    ("OOS",       OOS_temporal,      'steelblue'),
    ("Generated", diffusion_temporal,      '#2ca02c'),
    ("Resample",  resample_temporal, '#17becf'),
    ("Gaussion",  gaussian_temporal, '#ff7f0e'),
]
{n: a.shape for n, a, _ in tempo_sets}
# Out:
# {'OOS': (239, 7, 22),
#  'Generated': (500, 7, 22),
#  'Resample': (500, 7, 22),
#  'Gaussion': (500, 7, 22)}

# %%
def acf_curve(X, nlags=10, demean=True, bias_correct=False):
    # X:(M,F,T). ACF computed per (path,factor) along time, then averaged over M.
    Xc  = X - X.mean(axis=2, keepdims=True) if demean else X
    var = (Xc ** 2).mean(axis=2)                     # (M,F)
    out = []
    for k in range(1, nlags + 1):
        cov_k = (Xc[:, :, k:] * Xc[:, :, :-k]).mean(axis=2)   # (M,F)
        out.append((cov_k / var).mean(axis=0))                # mean over M -> (F,)
    acf = np.stack(out, axis=1)                                # (F,nlags)
    if bias_correct:
        acf = acf + 1.0 / X.shape[2]
    return acf                                                 # (F,nlags)

# %%
# 3.1 ACF of returns
NLAGS = 10
lags  = np.arange(1, NLAGS + 1)
acf_r = {n: acf_curve(a, NLAGS, demean=True, bias_correct=True)
         for n, a, _ in tempo_sets}

n_factors = len(FACTOR_NAMES)
fig, axes = plt.subplots(2, 4, figsize=(16, 7))
for ax, name, i in zip(axes.flatten(), FACTOR_NAMES, range(n_factors)):
    ax.axhline(0, color='k', lw=0.7, ls='--', alpha=0.6)
    for sname, _, col in tempo_sets:
        ls = '-' if sname in ('OOS', 'Generated') else '--'
        lw = 1.8 if sname in ('OOS', 'Generated') else 1.3
        ax.plot(lags, acf_r[sname][i], marker='o', ms=3,
                color=col, ls=ls, lw=lw, label=sname)
    ax.set_title(name, fontweight='bold')
    ax.set_xlabel('lag (days)'); ax.set_ylabel('ACF of returns')
    ax.legend(fontsize=6); ax.grid(True, alpha=0.3)
for ax in axes.flatten()[n_factors:]:
    ax.set_visible(False)
fig.suptitle(f'3.1 ACF of returns — linear unpredictability ',
             fontsize=13, fontweight='bold')
plt.tight_layout(); plt.show()

_oos = acf_r['OOS'].mean()
print(f"{'set':<12}{'mean ACF':>10}{'|gap vs OOS|':>14}")
print("-" * 36)
for sname, _, _ in tempo_sets:
    v = acf_r[sname].mean()
    gap = '' if sname == 'OOS' else f"{abs(v - _oos):>14.4f}"
    print(f"{sname:<12}{v:>10.4f}{gap}")
# Out:
# set           mean ACF  |gap vs OOS|
# ------------------------------------
# OOS            -0.0056
# Generated      -0.0023        0.0033
# Resample       -0.0019        0.0037
# Gaussion       -0.0029        0.0027

# %%
# 3.2 VolClust & CoarseFine
from metrics.statistic_temporal import registry as _treg
_tm = _treg.get_all()
_metrics = [("VolClust", _tm["VolClust"]), ("CoarseFine", _tm["CoarseFine"])]

_vals = {m: {n: float(f(a, a)) for n, a, _ in tempo_sets} for m, f in _metrics}

col_w = 12
header = f"{'metric':<12}" + "".join(f"{n:>{col_w}}" for n, _, _ in tempo_sets)
print("Temporal stylized facts (registry-aligned):")
print(header)
print("-" * len(header))
for m, _ in _metrics:
    row = f"{m:<12}" + "".join(f"{_vals[m][n]:>{col_w}.4f}" for n, _, _ in tempo_sets)
    print(row)
# Out:
# Temporal stylized facts (registry-aligned):
# metric               OOS   Generated    Resample    Gaussion
# ------------------------------------------------------------
# VolClust         -0.0440     -0.0440     -0.0373     -0.0463
# CoarseFine        0.0132      0.0126      0.0300      0.0047

# %%
# 3.3 variance ratio
hs = np.arange(1, seq_len + 1)

def var_ratio(X):                                  # X:(M,F,T) -> (F,T)
    C   = np.cumsum(X, axis=2)                      # cumulative return path
    sig = C.std(axis=0)                             # (F,T) std over scenarios
    return sig / (np.sqrt(hs) * sig[:, [0]])        # vr[:,0] == 1

vr_by = {n: var_ratio(a) for n, a, _ in tempo_sets}

n_factors = len(FACTOR_NAMES)
fig, axes = plt.subplots(2, 4, figsize=(16, 7))
for ax, name, i in zip(axes.flatten(), FACTOR_NAMES, range(n_factors)):
    ax.axhline(1.0, color='k', lw=0.8, ls='--', alpha=0.6)
    for sname, _, col in tempo_sets:
        ls = '-' if sname in ('OOS', 'Generated') else '--'
        lw = 1.8 if sname in ('OOS', 'Generated') else 1.3
        ax.plot(hs, vr_by[sname][i], color=col, ls=ls, lw=lw,
                marker='o', ms=3, label=sname)
    ax.set_title(name, fontweight='bold')
    ax.set_xlabel('horizon h (days)'); ax.set_ylabel('σ(h)/(√h·σ(1))')
    ax.legend(fontsize=7); ax.grid(True, alpha=0.3)
for ax in axes.flatten()[n_factors:]:
    ax.set_visible(False)
fig.suptitle('3.3 Variance ratio — volatility term structure ',
             fontsize=13, fontweight='bold')
plt.tight_layout(); plt.show()

# numeric: factor-averaged VR at short / mid / terminal horizon
mid = seq_len // 2
print(f"{'set':<12}{'VR(h=5)':>10}{f'VR(h={mid})':>10}{f'VR(h={seq_len})':>11}")
print("-" * 43)
for sname, _, _ in tempo_sets:
    v = vr_by[sname]
    print(f"{sname:<12}{v[:, 4].mean():>10.4f}{v[:, mid-1].mean():>10.4f}"
          f"{v[:, -1].mean():>11.4f}")
# Out:
# set            VR(h=5)  VR(h=11)   VR(h=22)
# -------------------------------------------
# OOS             0.9733    0.9411     0.8815
# Generated       1.0757    1.0764     1.0724
# Resample        0.9903    0.9580     0.9354
# Gaussion        1.0016    1.0185     1.0147

# %%
# 3.4 Max-drawdown distribution (per factor)
def max_drawdown(X):                                # X:(M,F,T) -> (M,F)
    eq   = np.cumprod(1.0 + X, axis=2)
    peak = np.maximum.accumulate(eq, axis=2)
    return (1.0 - eq / peak).max(axis=2)

mdd_by = {n: max_drawdown(a) for n, a, _ in tempo_sets}   # (M,F) per set

n_factors = len(FACTOR_NAMES)
fig, axes = plt.subplots(2, 4, figsize=(16, 7))
for ax, name, i in zip(axes.flatten(), FACTOR_NAMES, range(n_factors)):
    fi_all = np.concatenate([mdd_by[n][:, i] for n, _, _ in tempo_sets])
    bins   = np.linspace(0, np.quantile(fi_all, 0.995), 40)
    for sname, _, col in tempo_sets:
        ls = '-' if sname in ('OOS', 'Generated') else '--'
        lw = 1.9 if sname in ('OOS', 'Generated') else 1.3
        ax.hist(mdd_by[sname][:, i], bins=bins, histtype='step',
                density=True, color=col, lw=lw, ls=ls,
                label=f"{sname} ({mdd_by[sname][:, i].mean():.3f})")
    ax.set_title(name, fontweight='bold')
    ax.set_xlabel('Max drawdown (fraction)');
    ax.set_ylabel('density')
    ax.legend(fontsize=7); ax.grid(True, alpha=0.3)
for ax in axes.flatten()[n_factors:]:
    ax.set_visible(False)
fig.suptitle('3.4 Max-drawdown distribution',
             fontsize=13, fontweight='bold')
plt.tight_layout(); plt.show()

# %%
methods = [n for n, _, _ in tempo_sets if n != 'OOS']
w1_tab  = {mth: np.array([wasserstein_distance(mdd_by[mth][:, i],
                                               mdd_by['OOS'][:, i])
                          for i in range(n_factors)])
           for mth in methods}

col_w  = 14
header = f"{'factor':<14}" + "".join(f"{mth:>{col_w}}" for mth in methods)
print("W1 of max-drawdown distribution vs OOS")
print(header)
print("-" * len(header))
for i, name in enumerate(FACTOR_NAMES):
    vals = [w1_tab[mth][i] for mth in methods]
    win  = int(np.argmin(vals))
    row  = f"{name:<14}"
    for j, v in enumerate(vals):
        cell = f"{v:.4f}" + (" *" if j == win else "")
        row += f"{cell:>{col_w}}"
    print(row)
print("-" * len(header))
print(f"{'mean(|W1|)':<14}" + "".join(f"{w1_tab[mth].mean():>{col_w}.4f}"
                                       for mth in methods))
# Out:
# W1 of max-drawdown distribution vs OOS
# factor             Generated      Resample      Gaussion
# --------------------------------------------------------
# market              0.0121 *        0.0140        0.0161
# growth                0.0007        0.0008      0.0005 *
# momentum            0.0022 *        0.0029        0.0023
# quality             0.0009 *        0.0015        0.0015
# size                  0.0020      0.0015 *        0.0015
# value               0.0022 *        0.0027        0.0038
# volatility            0.0054        0.0033      0.0020 *
# --------------------------------------------------------
# mean(|W1|)            0.0036        0.0038        0.0039

# %%
# !jupyter nbconvert --to webpdf temporal_factor_evaluation.ipynb
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# [NbConvertApp] Converting notebook temporal_factor_evaluation.ipynb to webpdf
# [NbConvertApp] ERROR | Notebook JSON is invalid: Additional properties are not allowed ('jetTransient' was unexpected)
#
# Failed validating 'additionalProperties' in display_data:
#
# On instance['cells'][8]['outputs'][0]:
# {'data': {'image/png': 'iVBORw0KGgoAAAANSUhEUgAAA90AAAN2CAYAAADkFeqrAAAAOnRFWHRTb2Z0d2Fy...',
#           'text/plain': '<Figure size 1000x900 with 4 Axes>'},
#  'jetTransient': {'display_id': None},
#  'metadata': {},
#  'output_type': 'display_data'}
# [NbConvertApp] WARNING | Alternative text is missing on 8 image(s).
# [NbConvertApp] Building PDF
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 1171716 bytes to temporal_factor_evaluation.pdf
