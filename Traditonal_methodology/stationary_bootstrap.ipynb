# %%
import numpy as np

# %%
def sample(data, size):
    o = np.empty((size, data.shape[1]))
    r = np.random.default_rng(42)
    for it in range(size):
        ii = r.integers(0, data.shape[0])
        o[it] = data[ii]
    return o

# %%
data = np.load('stocknet_81.npy')

# %%
rng = np.random.default_rng(42)
p = 0.125

# %%
idx = rng.integers(0, data.shape[0])
out = np.empty(data.shape)

# %%
for t in range(data.shape[0]):
    out[t] = data[idx]
    if rng.random() < p:
        idx = rng.integers(0, data.shape[0])
    else:
        idx = (idx + 1) % data.shape[0]

# %%
out = sample(data, 4096)
out.shape
# Out:
# (4096, 81)

# %%
# dump to npy
np.save('SB4096.npy', out)

# %%
# Generate temporal samples [M, N, D] = [2048, 81, 22]
def sample_temporal(data, M, D, p=0.125, seed=42):
    """
    Stationary bootstrap for temporal sequences.
    Returns shape [M, N, D]: M scenarios, N assets, D days.
    Each scenario is a D-day path generated by the stationary bootstrap Markov chain.
    """
    T, N = data.shape
    rng = np.random.default_rng(seed)
    out = np.empty((M, N, D))
    for m in range(M):
        idx = rng.integers(0, T)
        for d in range(D):
            out[m, :, d] = data[idx]
            if rng.random() < p:
                idx = rng.integers(0, T)
            else:
                idx = (idx + 1) % T
    return out

data = np.load('../data/stocknet_81.npy')
out_temporal = sample_temporal(data, M=2048, D=22)
print(out_temporal.shape)  # (2048, 81, 22)
np.save('../samples/SB2048_T22.npy', out_temporal)
print("Saved to ../samples/SB2048_T22.npy")
